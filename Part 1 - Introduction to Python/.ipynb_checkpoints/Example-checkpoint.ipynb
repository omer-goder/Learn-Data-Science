# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print('hello world'.title())
# Out:
# Hello World

# %%
hello world
# Out:
#   File "<ipython-input-3-22596363b3de>", line 1
#     hello world
#               ^
# SyntaxError: invalid syntax

# %%
'hello world'
# Out:
# 'hello world'

# %%
'Hi'
# Out:
# 'Hi'

# %%
'hello'
# Out:
# 'hello'
